# %% [markdown]
# # Metody Obliczeniowe w Nauce i Technice Laboratorium 5
# ## Równania nieliniowe
# ### Błażej Kustra

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import time
import networkx as nx
import warnings

# %% [markdown]
# ### 1. Metoda Gaussa-Jordana
# Napisz i sprawdź funkcję rozwiązującą układ równań liniowych n × n metodą Gaussa-Jordana. Dla rozmiarów macierzy współczynników większych niż 500 × 500 porównaj czasy działania zaimplementowanej funkcji z czasami uzyskanymi dla wybranych funkcji bibliotecznych.

# %%
def create_linear_equation(n):
    M = np.random.randint(low=-100, high=100, size=(n, n)).astype(float)
    W = np.random.randint(low=1, high=100, size=n).astype(float)
    return M, W

# %%
def gauss_jordan(M, W):
    n = len(W)
    
    for i in range(n):   
        for j in range(i+1,n):
            if abs(M[j][i]) > abs(M[i][i]):
                M[[i, j]] = M[[j, i]] 
                W[i], W[j] = W[j], W[i]

    for i in range(n):
        scale = M[i][i]
        M[i] /= scale
        W[i] /= scale
        
        for j in range(n):
            if i == j: continue 
            scale = M[j][i] 
            M[j] -= M[i] * scale 
            W[j] -= W[i] * scale 
            
    return W

# %%
M, W = create_linear_equation(3)
print(M)
print(W)
print("linalg.solve: ", np.linalg.solve(M, W))
print("Gauss-Jordan: ", gauss_jordan(M, W))
# Out:
# [[  9.  54. -67.]
#  [ 48.  24. -37.]
#  [-96.  44. -59.]]
# [67. 79. 55.]
# linalg.solve:  [ 0.22760577 -5.53285275 -5.42874025]
# Gauss-Jordan:  [ 0.22760577 -5.53285275 -5.42874025]

# %%
def measure_time(M, W):
    start_np = time.time()
    np.linalg.solve(M, W)
    end_np = time.time()
    
    start_gauss = time.time()
    gauss_jordan(M, W)
    end_gauss = time.time()
    
    return end_np - start_np, end_gauss - start_gauss

# %%
time_np = []
time_gauss = []

for n in range(600):
    M, W = create_linear_equation(n)
    time_1, time_2 = measure_time(M, W)
    time_np.append(time_1)
    time_gauss.append(time_2)
    print(n, end="\r")

plt.plot(time_np,'r+')
plt.plot(time_gauss,'b+')
plt.show()
# Out:
# 599

# %% [markdown]
# Czas potrzebny do rozwiązania układu równań jest znacznie dłuższy niż funkcji $numpy.linalg.solve$, a różnica rośnie wraz ze wzrostem ilości elementów w macierzy.
#
# <img src="gauss-vs-linalg-solve.png">
# <center> zaimplementowany program (niebieski) </center>
# <center> funkcja np.linalg.solve (czerwony) </center>

# %% [markdown]
# ### 2. Faktoryzacja LU
# Napisz i sprawdź funkcję dokonującą faktoryzacji $A = LU$ macierzy $A$. Zastosuj częściowe poszukiwanie elementu wiodącego oraz skalowanie.

# %%
def LU_decomposition(M, n):
    L = [[0] * n for _ in range(n)] 
    U = [[0] * n for _ in range(n)]      
    
    for i in range(n): 
        for j in range(i, n):  #górny trójkąt
            sum = 0
            for k in range(i): 
                sum += L[i][k] * U[k][j]
            U[i][j] = M[i][j] - sum 

        for j in range(i, n): #dolny trójkąt
            L[i][i] = 1 
            if (i == j): continue
            sum = 0 
            for k in range(i): 
                sum += L[j][k] * U[k][i]
            L[j][i] = (M[j][i] - sum) / U[i][i]
            
    return L, U

# %%
A = np.random.randint(low=-10,high=10,size=(3,3)).astype(float)

L,U = LU_decomposition(A,3)
print("Macierz Wejściowa:")
for row in A: print(row)
    
print("\nL:")
for row in L: print(row)
    
print("\nU:")
for row in U: print(row)
    
print("\nL * U:")
for row in np.dot(L,U): print(row)
# Out:
# Macierz Wejściowa:
# [2. 4. 0.]
# [ 1. -8. -8.]
# [ -9.   7. -10.]
#
# L:
# [1, 0, 0]
# [0.5, 1, 0]
# [-4.5, -2.5, 1]
#
# U:
# [2.0, 4.0, 0.0]
# [0, -10.0, -8.0]
# [0, 0, -30.0]
#
# L * U:
# [2. 4. 0.]
# [ 1. -8. -8.]
# [ -9.   7. -10.]

# %% [markdown]
# ### 2. Analiza obwodu elektrycznego
# Napisz program, który:
#  1. Wczytuje z pliku listę krawędzi grafu opisującego obwód elektryczny. Wagi krawędzi określają opór fragmentu obwodu między dwoma węzłami. Wierzchołki grafu identyfikowane są przez liczby naturalne.
#  2. Wczytuje dodatkowo trójkę liczb $(s,t,E)$, przy czym para $(s,t)$ wskazuje między którymi węzłami sieci przyłożono siłę elektromotoryczną E. Opór wewnętrzny SEM można zaniedbać.
#  3. Wykorzystując prawa Kirchhoffa znajduje natężenia prądu w każdej części obwodu i przedstawia je na rysunku w postaci grafu ważonego z etykietami.
#  4. Wykorzystując metodę potencjałów węzłowych zaimplementuj alternatywne rozwiązanie problemu.
#  5. Przedstaw (wizualizacja + sprawdzenie poprawności wyników) działanie programu dla grafów spójnych mających od 15 do 100 wierzchołków:
#     - Spójny graf losowy
#     - Graf 3-regularny (kubiczny)
#     - Graf złożony z dwóch grafów losowych połączonych mostkiem
#     - Graf siatka 2D

# %%
epsilon = 1e-8

def kirchoff(G, s, t, E):
    if not nx.is_weakly_connected(G):
        raise Exception('Graf nie spójny.')

    if s not in G.nodes() or t not in G.nodes() or s == t:  # istnieja wierzcholki miedzy ktorymi przylozony jest E
        raise Exception('Zmienne s lub t są błędnie wprowadzone')

    G.add_edge(s, t, R=0)

    n = G.number_of_edges()
    M = np.zeros((n, n))
    W = np.zeros(n)

    edges = list(G.edges())
    cycles = nx.cycle_basis(G.to_undirected())
    for cycle in cycles:
        cycle.append(cycle[0])
    cycles_count = len(cycles)

    # II prawo kirchhoffa
    for i, cycle in enumerate(cycles):
        for j in range(len(cycle) - 1):
            pair = (cycle[j], cycle[j + 1])
            if pair == (s, t):
                W[i] = E
            elif pair == (t, s):
                W[i] = -E
            else:
                (u, v) = pair
                if (u, v) in edges:
                    j = edges.index((u, v))
                    M[i][j] = G[u][v]['R']
                elif (v, u) in edges:
                    j = edges.index((v, u))
                    M[i][j] = -G[v][u]['R']

    # I prawo kirchhoffa
    for i, vertex in enumerate(G.nodes()):
        if cycles_count + i < len(edges):  # jezeli brakuje nam rownan
            for (u, v) in G.out_edges(vertex):  # wszystkie 'wychodzące' z danego wierzchołka
                j = edges.index((u, v))
                M[cycles_count + i, j] = -1
            for (u, v) in G.in_edges(vertex):  # wszystkie 'wchodzace' do danego wierzchołka
                j = edges.index((u, v))
                M[cycles_count + i, j] = 1
        else:
            break

    if np.linalg.matrix_rank(M) != n:
        raise Exception("Brak rozwiazan")

    I = np.linalg.solve(M, W)

    for i, (u, v) in enumerate(G.copy().edges()):
        if I[i] < 0:
            I[i] = -I[i]
            tmp = G.edges[(u, v)]['R']
            G.remove_edge(u, v)
            G.add_edge(v, u, R=tmp)
            (u, v) = (v, u)
        G.edges[(u, v)]['I'] = I[i]

    # II prawo Kirchhoffa
    for i, cycle in enumerate(cycles):
        U = 0
        for i in range(len(cycle) - 1):
            pair = (cycle[i], cycle[i + 1])
            if pair == (s, t):
                U += E
            elif pair == (t, s):
                U -= E
            else:
                (u, v) = pair
                if (u, v) in G.edges():
                    U = U - G.edges[(u, v)]['R'] * G.edges[(u, v)]['I']
                elif (v, u) in edges:
                    U = U + G.edges[(v, u)]['R'] * G.edges[(v, u)]['I']
        if U > epsilon:
            raise Exception("Nie spełnia II prawa Kirchhoffa")

    # I prawo Kirchhoffa
    for x in G.nodes():
        I = 0
        for e in G.in_edges(x):
            I += G.edges[e]['I']
        for e in G.out_edges(x):
            I -= G.edges[e]['I']
        if I > epsilon:
            raise Exception("Nie spełnia I prawa Kirchhoffa")

    return G

# %%
from matplotlib.pyplot import figure
def draw_graph(G, pos, node_size = 200, color = 'white'):
    
    nx.draw_networkx_nodes(G, pos, node_color = 'purple', node_size = node_size)
    nx.draw_networkx_labels(G, pos, font_size = 12, font_color = color)

    nx.draw_networkx_edges(G, 
                           pos, 
                           edge_color=[I for _,I in nx.get_edge_attributes(G,'I').items()],
                           edge_cmap=plt.cm.BuPu,
                           edge_vmin=0.1, 
                           edge_vmax=1, 
                           arrowsize=16, 
                           node_size=node_size)
    
    edgeLabels = {e:'%.2f' %I for e,I in nx.get_edge_attributes(G,'I').items()}   
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edgeLabels, font_size = 8)
    plt.show()

# %%
n = 15
G = nx.DiGraph()
for u in range(n):
    for v in range(u, n):
        if random.random() < 0.314159: 
            G.add_edge(u, v, R = random.randint(1, 10))
            
stE = (0, 1, 10)
G = kirchoff(G, *stE)
draw_graph(G, nx.circular_layout(G))

# %%
G = nx.DiGraph()
for u, v in nx.petersen_graph().edges():
    G.add_edge(u, v, R=random.randint(0,10))

stE = (0, 1, 10)
pos = {0:[0,2], 1:[2,0], 2:[1,-3],3:[-1,-3], 4:[-2,0], 5:[0,1], 6:[1,0], 7:[0.7,-2], 8:[-0.7,-2],9:[-1,0]} 

G = kirchoff(G, *stE)
draw_graph(G, pos)

# %%
n = 8
G_1 = nx.DiGraph()
G_2 = nx.DiGraph()

for u in range(n):
    for v in range(u, n):
        if random.random() < 0.2137: 
            G_1.add_edge(u, v, R = random.randint(1, 10))
        if random.random() < 0.420: 
            G_2.add_edge(u+n, v+n, R = random.randint(1, 10))
            
G = nx.compose(G_1,G_2)
G.add_edge(1,n,R=1)

pos = {**nx.shell_layout(G_1), **{k: [xy[0], xy[1]+3] for k, xy in nx.shell_layout(G_2).items()}} 
stE = (0, n+1, 100)
G = kirchoff(G, *stE)
draw_graph(G, pos)

# %%
n = 4
G = nx.DiGraph()
for u, v in nx.grid_2d_graph(n, n).edges():
    G.add_edge(u, v, R=random.randint(0,10))

pos = {(i, j): [i, j] for i in range(n) for j in range(n)}

stE = ((0, 0), (1, 0), 100)
G = kirchoff(G, *stE)
draw_graph(G, pos, 50, 'purple')

# %%
def graph_from_file(filepath):
    file = open(filepath, 'r') 
    lines = file.read().replace(" ", "").split("\n")

    G = nx.DiGraph()

    stE = lines.pop(0)
    stE = list(map(lambda arg: int(arg), stE.split(',')))

    for line in lines:
        argument = line.split(",")
        G.add_edge(int(argument[0]), int(argument[1]), R = random.randint(1, 10))

    return kirchoff(G, *stE)

# %%
G = graph_from_file('graph1.txt')
draw_graph(G, nx.circular_layout(G))

# %%
G = graph_from_file('graph2.txt')
draw_graph(G, nx.circular_layout(G))
